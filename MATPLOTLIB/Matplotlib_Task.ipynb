# %% [markdown]
# # Data Visualization with Matplotlib

# %% [markdown]
# RUN THE CELL BELOW AND START SOLVING

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# Plot (x,y) axes and set the labels and titles <br>
# Use ax.plot function to plot a simple sinusoid to match the plot below <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
#define sine function
x = np.arange(0,10,0.1)
y = np.sin(x)

#plot the sine curve
plt.plot(x,y)
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
# your code here

# %% [markdown]
# #define sine function
# x = np.arange(0,10,0.1)
# y = np.sin(x)Use Scatter Plots to draw below as the given output <br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
#define sine function
x = np.linspace(0,10,30) #used linspace instead of arange to have more spacing between points
y = np.sin(x)

# plot scatter with black markers
markercolor = ['black']
plt.scatter(x,y, )
plt.scatter(x,y, c=markercolor)
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
# your code here-

# %% [markdown]
# use line and color codes to plot points along with a line connecting them<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
# plot scatter with black markers connected with lines
markercolor = ['black']
plt.plot(x,y,'k-o')
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.show()

# %%
#your code here-

# %% [markdown]
# create a single figure with multiple lines as follows<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
x = np.arange(0,10,0.1)
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1,x,y2)
plt.show()

# %%
# your code here-

# %% [markdown]
# Create the plot given below in the output by using 'linestyle'  keyword.<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(x, x + 0, linestyle='-')
plt.plot(x, x + 1, linestyle='--')
plt.plot(x, x + 2, linestyle='-.')
plt.plot(x, x + 3, linestyle=':')
plt.plot(x, x + 4, linestyle='-')  
plt.plot(x, x + 5, linestyle='--') 
plt.plot(x, x + 6, linestyle='-.') 
plt.plot(x, x + 7, linestyle=':')

# %% [markdown]
# use 'linestyle' and 'color' keyword  to draw as given below in the output<br>
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
plt.plot(x, x + 0, '-g')
plt.plot(x, x + 1, '--c')
plt.plot(x, x + 2, '-.k')
plt.plot(x, x + 3, ':r')

# %%
# your code here-

# %% [markdown]
# # GOOD JOB!!
